# %% [markdown]
# **Samineni Jayaprakash| Data Science intern | Oasis Infobye | # Task 2**

# %% [markdown]
# # UNEMPLOYEMENT ANALYSIS WITH PYTHON

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
#importing libraries
#import pandas library and make it as pd
import pandas as pd
#import matplotlib library and make it as plt
import matplotlib.pyplot as plt
#import numpy library and make it as np
import numpy as np
#import seaborn library and make it as sns
import seaborn as sns
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# **IMPORTING DATASET OF UNEMPLOYMENT RATE IN INDIA :**

# %%
data=pd.read_csv("Unemployment_Rate_upto_11_2020.csv")
data
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0               16635535                                     41.02    South
# 1               16545652                                     40.90    South
# 2               15881197                                     39.18    South
# 3               11336911                                     33.10    South
# 4               12988845                                     36.46    South
# ..                   ...                                       ...      ...
# 262             30726310                                     40.39     East
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 0      15.9129    79.740
# 1      15.9129    79.740
# 2      15.9129    79.740
# 3      15.9129    79.740
# 4      15.9129    79.740
# ..         ...       ...
# 262    22.9868    87.855
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# 266    22.9868    87.855
#
# [267 rows x 9 columns]

# %%
#head-->first five rows
data.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# 1    15.9129     79.74
# 2    15.9129     79.74
# 3    15.9129     79.74
# 4    15.9129     79.74

# %%
#tail--> last five rows
data.tail()
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 262  West Bengal   30-06-2020          M                              7.29
# 263  West Bengal   31-07-2020          M                              6.83
# 264  West Bengal   31-08-2020          M                             14.87
# 265  West Bengal   30-09-2020          M                              9.35
# 266  West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 262             30726310                                     40.39     East
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 262    22.9868    87.855
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# 266    22.9868    87.855

# %%
#shows shape of the dataset
data.shape
# Out:
# (267, 9)

# %%
#information of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
data.info
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0               16635535                                     41.02    South
# 1               16545652                                     40.90    South
# 2               15881197                                     39.18    South
# 3               11336911                                     33.10    South
# 4               12988845                                     36.46    South
# ..                   ...                                       ...      ...
# 262             30726310                                     40.39     East
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 0      15.9129    79.740
# 1      15.9129    79.740
# 2      15.9129    79.740
# 3      15.9129    79.740
# 4      15.9129    79.740
# ..         ...       ...
# 262    22.9868    87.855
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# 266    22.9868    87.855
#
# [267 rows x 9 columns]>

# %%
# data type of the each column
data.dtypes
# Out:
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                           int64
#  Estimated Labour Participation Rate (%)    float64
# Region.1                                     object
# longitude                                   float64
# latitude                                    float64
# dtype: object

# %%
# describe the summuray of the dataset
data.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# 25%                                   37.265000   18.112400   76.085600
# 50%                                   40.390000   23.610200   79.019300
# 75%                                   44.055000   27.278400   85.279900
# max                                   69.690000   33.778200   92.937600

# %%
#check null values
data.isna().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
# sum of the null values
data.isna().sum().sum()
# Out:
# 0

# %%
#check duplicate values
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 262    False
# 263    False
# 264    False
# 265    False
# 266    False
# Length: 267, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.columns=["States","Date","Frequency","Estimated unemployment rate","Estimated employed","Estimation labour participation rate","Region","Longitude","Latitude"]

# %%
data.head()
# Out:
#            States         Date Frequency  Estimated unemployment rate  \
# 0  Andhra Pradesh   31-01-2020         M                         5.48
# 1  Andhra Pradesh   29-02-2020         M                         5.83
# 2  Andhra Pradesh   31-03-2020         M                         5.79
# 3  Andhra Pradesh   30-04-2020         M                        20.51
# 4  Andhra Pradesh   31-05-2020         M                        17.43
#
#    Estimated employed  Estimation labour participation rate Region  Longitude  \
# 0            16635535                                 41.02  South    15.9129
# 1            16545652                                 40.90  South    15.9129
# 2            15881197                                 39.18  South    15.9129
# 3            11336911                                 33.10  South    15.9129
# 4            12988845                                 36.46  South    15.9129
#
#    Latitude
# 0     79.74
# 1     79.74
# 2     79.74
# 3     79.74
# 4     79.74

# %%
data.drop(columns=["Frequency"],inplace=True)

# %%
data["Region"].value_counts()
# Out:
# Region
# North        79
# South        60
# West         50
# East         40
# Northeast    38
# Name: count, dtype: int64

# %%
sns.countplot(x="Region",data=data)
plt.title("India Unemployment")
plt.show()

# %%
data["Date"].value_counts()
# Out:
# Date
#  31-03-2020    27
#  31-05-2020    27
#  30-06-2020    27
#  31-07-2020    27
#  31-08-2020    27
#  30-09-2020    27
#  31-10-2020    27
#  31-01-2020    26
#  29-02-2020    26
#  30-04-2020    26
# Name: count, dtype: int64

# %%
data["Date"].unique()
# Out:
# array([' 31-01-2020', ' 29-02-2020', ' 31-03-2020', ' 30-04-2020',
#        ' 31-05-2020', ' 30-06-2020', ' 31-07-2020', ' 31-08-2020',
#        ' 30-09-2020', ' 31-10-2020'], dtype=object)

# %%
data
# Out:
#              States         Date  Estimated unemployment rate  \
# 0    Andhra Pradesh   31-01-2020                         5.48
# 1    Andhra Pradesh   29-02-2020                         5.83
# 2    Andhra Pradesh   31-03-2020                         5.79
# 3    Andhra Pradesh   30-04-2020                        20.51
# 4    Andhra Pradesh   31-05-2020                        17.43
# ..              ...          ...                          ...
# 262     West Bengal   30-06-2020                         7.29
# 263     West Bengal   31-07-2020                         6.83
# 264     West Bengal   31-08-2020                        14.87
# 265     West Bengal   30-09-2020                         9.35
# 266     West Bengal   31-10-2020                         9.98
#
#      Estimated employed  Estimation labour participation rate Region  \
# 0              16635535                                 41.02  South
# 1              16545652                                 40.90  South
# 2              15881197                                 39.18  South
# 3              11336911                                 33.10  South
# 4              12988845                                 36.46  South
# ..                  ...                                   ...    ...
# 262            30726310                                 40.39   East
# 263            35372506                                 46.17   East
# 264            33298644                                 47.48   East
# 265            35707239                                 47.73   East
# 266            33962549                                 45.63   East
#
#      Longitude  Latitude
# 0      15.9129    79.740
# 1      15.9129    79.740
# 2      15.9129    79.740
# 3      15.9129    79.740
# 4      15.9129    79.740
# ..         ...       ...
# 262    22.9868    87.855
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# 266    22.9868    87.855
#
# [267 rows x 8 columns]

# %%
data["States"].value_counts()
# Out:
# States
# Andhra Pradesh      10
# Assam               10
# Uttarakhand         10
# Uttar Pradesh       10
# Tripura             10
# Telangana           10
# Tamil Nadu          10
# Rajasthan           10
# Punjab              10
# Puducherry          10
# Odisha              10
# Meghalaya           10
# Maharashtra         10
# Madhya Pradesh      10
# Kerala              10
# Karnataka           10
# Jharkhand           10
# Himachal Pradesh    10
# Haryana             10
# Gujarat             10
# Goa                 10
# Delhi               10
# Chhattisgarh        10
# Bihar               10
# West Bengal         10
# Jammu & Kashmir      9
# Sikkim               8
# Name: count, dtype: int64

# %%
data1=data.drop(columns=["States","Date","Region"])

# %%
data1
# Out:
#      Estimated unemployment rate  Estimated employed  \
# 0                           5.48            16635535
# 1                           5.83            16545652
# 2                           5.79            15881197
# 3                          20.51            11336911
# 4                          17.43            12988845
# ..                           ...                 ...
# 262                         7.29            30726310
# 263                         6.83            35372506
# 264                        14.87            33298644
# 265                         9.35            35707239
# 266                         9.98            33962549
#
#      Estimation labour participation rate  Longitude  Latitude
# 0                                   41.02    15.9129    79.740
# 1                                   40.90    15.9129    79.740
# 2                                   39.18    15.9129    79.740
# 3                                   33.10    15.9129    79.740
# 4                                   36.46    15.9129    79.740
# ..                                    ...        ...       ...
# 262                                 40.39    22.9868    87.855
# 263                                 46.17    22.9868    87.855
# 264                                 47.48    22.9868    87.855
# 265                                 47.73    22.9868    87.855
# 266                                 45.63    22.9868    87.855
#
# [267 rows x 5 columns]

# %%
data1.corr()
# Out:
#                                       Estimated unemployment rate  \
# Estimated unemployment rate                              1.000000
# Estimated employed                                      -0.245176
# Estimation labour participation rate                    -0.073540
# Longitude                                                0.149976
# Latitude                                                -0.023976
#
#                                       Estimated employed  \
# Estimated unemployment rate                    -0.245176
# Estimated employed                              1.000000
# Estimation labour participation rate           -0.047948
# Longitude                                      -0.113664
# Latitude                                       -0.119321
#
#                                       Estimation labour participation rate  \
# Estimated unemployment rate                                      -0.073540
# Estimated employed                                               -0.047948
# Estimation labour participation rate                              1.000000
# Longitude                                                         0.080372
# Latitude                                                          0.397836
#
#                                       Longitude  Latitude
# Estimated unemployment rate            0.149976 -0.023976
# Estimated employed                    -0.113664 -0.119321
# Estimation labour participation rate   0.080372  0.397836
# Longitude                              1.000000  0.125895
# Latitude                               0.125895  1.000000

# %%
sns.pairplot(data)
plt.show()

# %%
#the heat map to see correlation
plt.figure(figsize=(15,5))
sns.heatmap(data1.corr(),annot=True,cmap="Oranges_r")
plt.show()

# %% [markdown]
# # ESTIMATED EMPLOYED

# %%
data
# Out:
#              States         Date  Estimated unemployment rate  \
# 0    Andhra Pradesh   31-01-2020                         5.48
# 1    Andhra Pradesh   29-02-2020                         5.83
# 2    Andhra Pradesh   31-03-2020                         5.79
# 3    Andhra Pradesh   30-04-2020                        20.51
# 4    Andhra Pradesh   31-05-2020                        17.43
# ..              ...          ...                          ...
# 262     West Bengal   30-06-2020                         7.29
# 263     West Bengal   31-07-2020                         6.83
# 264     West Bengal   31-08-2020                        14.87
# 265     West Bengal   30-09-2020                         9.35
# 266     West Bengal   31-10-2020                         9.98
#
#      Estimated employed  Estimation labour participation rate Region  \
# 0              16635535                                 41.02  South
# 1              16545652                                 40.90  South
# 2              15881197                                 39.18  South
# 3              11336911                                 33.10  South
# 4              12988845                                 36.46  South
# ..                  ...                                   ...    ...
# 262            30726310                                 40.39   East
# 263            35372506                                 46.17   East
# 264            33298644                                 47.48   East
# 265            35707239                                 47.73   East
# 266            33962549                                 45.63   East
#
#      Longitude  Latitude
# 0      15.9129    79.740
# 1      15.9129    79.740
# 2      15.9129    79.740
# 3      15.9129    79.740
# 4      15.9129    79.740
# ..         ...       ...
# 262    22.9868    87.855
# 263    22.9868    87.855
# 264    22.9868    87.855
# 265    22.9868    87.855
# 266    22.9868    87.855
#
# [267 rows x 8 columns]

# %%
 #Assuming you have a DataFrame named 'df' with 'States' and 'Estimated Employed' columns
sum_employees_by_region = data.groupby("Region")["Estimated employed"].sum().reset_index()
# Now, 'sum_employees_by_state' contains the sum of employees for each state
print(sum_employees_by_region)
# Out:
#       Region  Estimated employed
# 0       East           784094676
# 1      North          1032726546
# 2  Northeast           137450010
# 3      South           842435360
# 4       West           931175636

# %%
x = data[['Region', 'Estimated employed']].groupby('Region').sum()
x.plot(kind='pie', autopct='%1.1f%%', subplots=True, figsize=(15, 7), title='Estimated Employed by percentage')
plt.axis('equal') # This line ensures that the pie chart is circular.
plt.show()

# %%
# Sort the DataFrame by the 'Estimated Employed' column in ascending order
sum_employees_by_region_sorted = sum_employees_by_region.sort_values(by='Estimated employed')
plt.figure(figsize=(12, 6))
plt.bar(sum_employees_by_region_sorted['Region'], sum_employees_by_region_sorted['Estimated employed'])
plt.title("Sum of Employees by region (Ascending Order)")
plt.xlabel('Region')
plt.ylabel('Sum of Employees')
plt.xticks(rotation=65) # Rotate x-axis labels for better readability
plt.show()

# %%
 #Assuming you have a DataFrame named 'data' with 'States' and 'Estimated Employed' columns
sum_employees_by_state = data.groupby('States')['Estimated employed'].sum().reset_index()
# Now, 'sum_employees_by_state' contains the sum of employees for each state
print(sum_employees_by_state)
# Out:
#               States  Estimated employed
# 0     Andhra Pradesh           154254800
# 1              Assam           108102755
# 2              Bihar           236068280
# 3       Chhattisgarh            84213492
# 4              Delhi            46328219
# 5                Goa             4423748
# 6            Gujarat           227307461
# 7            Haryana            68440590
# 8   Himachal Pradesh            20338849
# 9    Jammu & Kashmir            29790285
# 10         Jharkhand            87706424
# 11         Karnataka           216240176
# 12            Kerala            85967949
# 13    Madhya Pradesh           223183353
# 14       Maharashtra           392047582
# 15         Meghalaya            13498153
# 16            Odisha           127268329
# 17        Puducherry             3652629
# 18            Punjab            87830342
# 19         Rajasthan           197317522
# 20            Sikkim             1876186
# 21        Tamil Nadu           219878981
# 22         Telangana           162440825
# 23           Tripura            13972916
# 24     Uttar Pradesh           555247990
# 25       Uttarakhand            27432749
# 26       West Bengal           333051643

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Assuming you have a DataFrame named 'sum_employees_by_state' with 'States' and 'Estimated Employed' columns
# Sort the DataFrame by the 'Estimated Employed' column in ascending order
sum_employees_by_state_sorted = sum_employees_by_state.sort_values(by='Estimated employed')
plt.figure(figsize=(12, 6))
plt.bar(sum_employees_by_state_sorted['States'], sum_employees_by_state_sorted['Estimated employed'])
plt.title("Sum of Employees by State (Ascending Order)")
plt.xlabel('State')
plt.ylabel('Sum of Employees')
plt.xticks(rotation=65) # Rotate x-axis labels for better readability
plt.show()

# %%
 import pandas as pd
import matplotlib.pyplot as plt
# Assuming you have a DataFrame named 'sum_employees_by_state' with 'States' and 'Estimated Employed' columns
plt.figure(figsize=(12, 6))
plt.bar(sum_employees_by_state['States'], sum_employees_by_state['Estimated employed'].sort_values().index)
plt.title("Sum of Employees by State")
plt.xlabel('State')
plt.ylabel('Sum of Employees')
plt.xticks(rotation=90) # Rotate x-axis labels for better readability
plt.show()

# %%
plt.figure(figsize=(18,14))
sns.histplot(x='Estimated employed', hue='States', data=data, bins=20)
# add axes:
plt.title("Histogram of Estimated Employed by State")
plt.xlabel('Estimated employed')
plt.ylabel('Frequency')
# display the plot:
plt.show()

# %% [markdown]
# # LABOUR PATICIPATION RATE

# %%
x = data[['Region', 'Estimation labour participation rate']].groupby('Region').sum()
x.plot(kind='pie', autopct='%1.1f%%', subplots=True, figsize=(15, 7), title='Labour Participation Rate by Region')
plt.axis('equal') # This line ensures that the pie chart is circular.
plt.show()

# %%
# average Labour Participation rate by state wise:
sns.set(style="whitegrid")
plt.figure(figsize=(18, 6))
order = data.groupby('States')['Estimation labour participation rate'].mean().sort_values().index
sns.barplot(x='States', y='Estimation labour participation rate', data=data, order=order)
# add axes
plt.title("Average Labour Participation Rate")
plt.xlabel('States')
plt.ylabel('Estimation Labour Participation Rate')
plt.xticks(rotation=65) # Rotate x-axis labels for better readability
# display the plot:
plt.show()

# %% [markdown]
# # ESTIMATED UNEMPLOYMENT RATE:

# %%
x = data[['Region', 'Estimated unemployment rate']].groupby('Region').sum()
x.plot(kind='pie', autopct='%1.1f%%', subplots=True, figsize=(15, 7), title='Unemployment Rate by Region')
# This line ensures that the pie chart is circular.
plt.axis('equal') 
# display the plot:
plt.show()

# %%
 #Average Unemployment rate by region
sns.set(style="whitegrid")
plt.figure(figsize=(18, 6))
order = data.groupby('Region')['Estimated unemployment rate'].mean().sort_values().index
sns.barplot(x='Region', y='Estimated unemployment rate', data=data, order=order)
# add axes
plt.title("Average Unemployment Rate by Region")
plt.xlabel('Region')
plt.ylabel('Estimated Unemployment Rate')
# Rotate x-axis labels for better readability
plt.xticks(rotation=65) # Rotate x-axis labels for better readability
# display the plot:
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='States',y='Estimated unemployment rate',data=data)
plt.xticks(rotation=65) # Rotate x-axis labels for better readability
plt.show()

# %%
#average Unemployment rate state wise:
sns.set(style="whitegrid")
plt.figure(figsize=(18, 6))
order = data.groupby('States')['Estimated unemployment rate'].mean().sort_values().index
sns.barplot(x='States', y='Estimated unemployment rate', data=data, order=order)
# add axes
plt.title("Average Unemployment Rate by States")
plt.xlabel('States')
plt.ylabel('Estimated Unemployment Rate')
plt.xticks(rotation=65) # Rotate x-axis labels for better readability
# display the plot:
plt.show()
