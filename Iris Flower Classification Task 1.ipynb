# %% [markdown]
# **Samineni Jayaprakash| Data Science intern | Oasis Infobye | # Task 1**

# %% [markdown]
# # IRIS FLOWER CLASSIFICATION

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
#importing libraries
#import pandas library and make it as pd
import pandas as pd
#import matplotlib library and make it as plt
import matplotlib.pyplot as plt
#import numpy library and make it as np
import numpy as np
#import seaborn library and make it as sns
import seaborn as sns
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# **IMPORTING DATASET**

# %%
data=pd.read_csv("Iris (1).csv")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# **DATA EXPLORATION**

# %%
#check shape of the data
data.shape
# Out:
# (150, 6)

# %%
#check basic information of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#check statistical summary of the data
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#check null vallues in the data
data.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
print(data["Species"].nunique())
print(data["Species"].unique())
# Out:
# 3
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# **DATA VISUVALIZATION**

# %%
sns.pairplot(data,hue="Species",markers="*")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.scatterplot(x="SepalLengthCm",y="PetalLengthCm",data=data,hue="Species")
plt.subplot(1,2,2)
sns.scatterplot(x="SepalWidthCm",y="PetalWidthCm",data=data,hue="Species")
plt.show()

# %%
#correlation
data1=pd.read_csv("Iris (1).csv",usecols=["Id","SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"])
data1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
data1.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
#the heat map to see correlation
plt.figure(figsize=(15,5))
sns.heatmap(data1.corr(),annot=True,cmap="Oranges_r")
plt.show()

# %%
sns.jointplot(data=data,x="SepalLengthCm",y="SepalWidthCm", hue ="Species")
plt.show()

# %%
sns.jointplot(data=data,x="PetalLengthCm",y="PetalWidthCm", hue ="Species")
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(2,2,1)
sns.barplot(x="Species",y="SepalLengthCm",data=data,palette=("Spectral"))
plt.title("barplot SepleLengthCm vs Species")

plt.subplot(2,2,2)
sns.boxplot(x="Species",y="SepalLengthCm",data=data,palette=("Spectral"))
plt.title("barplot SepleLengthCm vs Species")


plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(2,2,1)
sns.barplot(x="Species",y="SepalLengthCm",data=data,palette=("coolwarm"))
plt.title("barplot SepleLengthCm vs Species")

plt.subplot(2,2,2)
sns.boxplot(x="Species",y="SepalLengthCm",data=data,palette=("coolwarm"))
plt.title("barplot SepleLengthCm vs Species")

# display the plot
plt.show()

# %%
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
sns.distplot(data["SepalLengthCm"],color="y").set_title("sepal length interval")
 
plt.subplot(2,2,2)
sns.distplot(data["SepalWidthCm"],color="r").set_title("sepal width interval")

plt.subplot(2,2,3)
sns.distplot(data["PetalLengthCm"],color="g").set_title("petal length interval")

plt.subplot(2,2,4)
sns.distplot(data["PetalWidthCm"],color="b").set_title("petal width interval")

plt.show()

# %% [markdown]
# # Data Cleaning

# %%
#change categorical data into numeric value
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data["Species"]=le.fit_transform(data["Species"])
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
data["Species"].unique()
# Out:
# array([0, 1, 2])

# %%
x=data.iloc[:,[0,1,2,3]]
x.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0   1            5.1           3.5            1.4
# 1   2            4.9           3.0            1.4
# 2   3            4.7           3.2            1.3
# 3   4            4.6           3.1            1.5
# 4   5            5.0           3.6            1.4

# %%
y=data.iloc[:,-1]
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Species, dtype: int32

# %%
print(x.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
#value counts of  species
data["Species"].value_counts()
# Out:
# Species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %% [markdown]
# # MODEL BUILDING

# %% [markdown]
# **split data into training and testing data:**

# %%
#we need to split  the data for training and testing:
from sklearn.model_selection import train_test_split
#train-70
#test-30
x=data.drop(columns=["Species"])
y=data["Species"]
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (112, 5)
# (38, 5)
# (112,)
# (38,)

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# print metric to get performance:
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 100.0

# %%
#KNN k_nearest neighbors
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 100.0

# %%
#decision tree:
from sklearn.tree import DecisionTreeClassifier
model= DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy:",model.score(x_test,y_test)*100)
# Out:
# Accuracy: 97.36842105263158

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_predict=knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
accuracy=accuracy_score(y_test,y_predict)
confusion=confusion_matrix(y_test,y_predict)

# %%
print(f"Accuracy:{accuracy:2f}")
# Out:
# Accuracy:1.000000

# %%
print("confusion_matrix")
print(confusion)
# Out:
# confusion_matrix
# [[13  0  0]
#  [ 0 16  0]
#  [ 0  0  9]]

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print(classification_report(y_predict,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00         9
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38

# %% [markdown]
# **HERE Iris-setosa indicates     0
#        Iris-versicolor indicates 1
#        Iris-virginica indicates  2
